# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text

import json

json.loads(r.text)

# 「r.text」讀出來的資料是全部都印在同一行的字串
# json.loads(r.text)」讀出來的資料有分行印出,較容易閱讀
# Out:
# [{'id': '11646385862',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 3767634,
#    'login': 'arezen',
#    'display_login': 'arezen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arezen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3767634?'},
#   'repo': {'id': 222569865,
#    'name': 'argoden/CICD_Docker',
#    'url': 'https://api.github.com/repos/argoden/CICD_Docker'},
#   'payload': {'action': 'closed',
#    'number': 6,
#    'pull_request': {'url': 'https://api.github.com/repos/argoden/CICD_Docker/pulls/6',
#     'id': 382016633,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyMDE2NjMz',
#     'html_url': 'https://github.com/argoden/CICD_Docker/pull/6',
#     'diff_url': 'https://github.com/argoden/CICD_Docker/pull/6.diff',
#     'patch_url': 'https://github.com/argoden/CICD_Docker/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/argoden/CICD_Docker/issues/6',
#     'number': 6,
#     'state': 'closed',
#     'locked': False,
# ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

# get
# r1 = requests.get("https://cat-fact.herokuapp.com/facts", params={'key': 'value'})
# json.loads(r1.text)

# post
r2 = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r2.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e5b7c28-d7a1e5a5ad2cc7d83db0c077'},
#  'json': None,
#  'origin': '119.77.207.240',
#  'url': 'http://httpbin.org/post'}

# %%
import requests
import json

# get
# r1 = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel', params = {'key':'value'})
# json.loads(r1.text)

# post
r2 = requests.post('http://odata.wra.gov.tw/v4/RealtimeWaterLevel', data = {'key':'value'})
json.loads(r2.text)
# Out:
# {'error': {'code': '',
#   'message': "No HTTP resource was found that matches the request URI 'http://wrisp2:88/odata/dataset/RealtimeWaterLevel'."}}
